# %% [markdown]
# # Generative Molecular Transformer
#
# Overview An autoregressive Transformer model trained on the Tox21 dataset to generate valid chemical structures (SMILES). Implemented in PyTorch from scratch without using nn.Transformer layers to demonstrate understanding of Multi-Head Attention mechanisms.
#
# Key Features
#
# Custom Attention Implementation: Manual implementation of Query/Key/Value projections and Causal Masking.
#
# Chem-Informatics: Integration with RDKit for validity checking and visualization.
#
# Results: Achieved 65% validity in generated molecules after 50 epochs.
#
# Installation pip install -r requirements.txt
#
# Attribution Code structure adapted from J.M. Tomczak's "Introduction to Deep Generative Modeling".

# %% [markdown]
# Code can be downloaded from the author's Github page https://github.com/jmtomczak/intro_dgm.

# %%
#!pip install torch numpy matplotlib pandas scikit-learn rdkit

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn import datasets
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F

import pandas as pd
import rdkit
from rdkit import Chem
from rdkit.Chem import Draw
#import deepchem

from pytorch_model_summary import summary

# %% [markdown]
# ### Dataset

# %% [markdown]
# This dataset is a slight modification of a widely used benchmark Tox21 (more [here](https://deepchem.readthedocs.io/en/latest/api_reference/moleculenet.html)). Each molecule is originally represented as SMILES and then tokenized (we used [`BasicSmileTokenizer`](https://deepchem.readthedocs.io/en/latest/api_reference/featurizers.html?highlight=tokenizer#basicsmilestokenizer) from [`DeepChem`](https://deepchem.readthedocs.io/en/latest/index.html)). We limit ourselves to SMILES no longer than 100 tokens and no smaller than 10 tokens. The resulting data is a matrix $7410 \times 100$ containing integers.

# %%
class Tox21(Dataset):
    """A filtered version of DeepChem Tox21 dataset. (Only SMILES longer than 9 and shorter than 101, the number of token values: 112)"""

    def __init__(self, mode='train', transforms=None):
        smiles = np.load(os.path.join('molecules', 'tox21_smiles_tokenized.npy'), allow_pickle=True)
        smiles = torch.from_numpy(smiles).long()
        
        if mode == 'train':
            self.data = smiles[:6600]
        elif mode == 'val':
            self.data = smiles[6600:7000]
        else:
            self.data = smiles[7000:]

        self.transforms = transforms

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data[idx]
        if self.transforms:
            sample = self.transforms(sample)
        return sample

# %% [markdown]
# ## Transformers: A combination of Multi-head Self-Attention, LayerNormalization and MLP

# %% [markdown]
# ### Architecture Note: Causal Masking
# To function as an Autoregressive Model (ARM), the network must generate molecules one token at a time without "peeking" at future tokens during training.
#
# While Recurrent Neural Networks (RNNs) enforce this sequentially, Transformers process the entire sequence in parallel. To enforce causality, this implementation uses **Masked Self-Attention**. In the `MultiHeadSelfAttention` block, we utilize `torch.triu_indices` to create an upper-triangular mask. This sets all attention scores for future positions to `-inf` before the softmax step, effectively zeroing out their probability and ensuring prediction $t$ depends only on tokens $0$ to $t-1$.

# %%
class MultiHeadSelfAttention(nn.Module):
    def __init__(self, num_emb, num_heads=8):
        super().__init__()
        
        # hyperparams
        self.D = num_emb
        self.H = num_heads
        
        # weights for self-attention
        self.w_k = nn.Linear(self.D, self.D * self.H)
        self.w_q = nn.Linear(self.D, self.D * self.H)
        self.w_v = nn.Linear(self.D, self.D * self.H)
        
        # weights for a combination of multiple heads
        self.w_c = nn.Linear(self.D * self.H, self.D)
            
    def forward(self, x, causal=True):
        # x: B(atch) x T(okens) x D(imensionality)
        B, T, D = x.size()
        
        # keys, queries, values
        k = self.w_k(x).view(B, T, self.H, D) # B x T x H x D
        q = self.w_q(x).view(B, T, self.H, D) # B x T x H x D
        v = self.w_v(x).view(B, T, self.H, D) # B x T x H x D
        
        k = k.transpose(1, 2).contiguous().view(B * self.H, T, D) # B*H x T x D
        q = q.transpose(1, 2).contiguous().view(B * self.H, T, D) # B*H x T x D
        v = v.transpose(1, 2).contiguous().view(B * self.H, T, D) # B*H x T x D
        
        k = k / (D**0.25) # scaling 
        q = q / (D**0.25) # scaling
        
        # kq
        kq = torch.bmm(q, k.transpose(1, 2)) # B*H x T x T
        
        # if causal
        if causal:
            mask = torch.triu_indices(T, T, offset=1) #It's useful when you want to operate on or extract elements 
            #from the upper triangular portion of a matrix (including the main diagonal) without explicitly constructing 
            #the full matrix and then selecting parts.This is particularly efficient for memory and computation,
            #especially when dealing with large matrices.
            kq[..., mask[0], mask[1]] = float('-inf')
        
        # softmax
        skq = F.softmax(kq, dim=2)
        
        # self-attention
        sa = torch.bmm(skq, v) # B*H x T x D
        sa = sa.view(B, self.H, T, D) # B x H x T x D
        sa = sa.transpose(1, 2) # B x T x H x D
        sa = sa.contiguous().view(B, T, D * self.H) # B x T x D*H
        
        out = self.w_c(sa) # B x T x D
        
        return out

# %% [markdown]
# ### Architecture Note: Positional Encodings
# Unlike RNNs, the self-attention mechanism is **permutation equivariant**—it calculates relationships between tokens based on content, not distance. Without explicit positional information, the model would treat a SMILES string like `C-O-C` identically to `C-C-O`.
#
# To resolve this, we inject order information using **Learnable Positional Embeddings** (`self.positional_embedding`). These vectors are added to the semantic token embeddings at the input layer, allowing the model to distinguish between atoms based on their specific position in the molecular sequence.

# %%
class TransformerBlock(nn.Module):
    def __init__(self, num_emb, num_neurons, num_heads=4):
        super().__init__()
        
        # hyperparams
        self.D = num_emb
        self.H = num_heads
        self.neurons = num_neurons
        
        # components
        self.msha = MultiHeadSelfAttention(num_emb=self.D, num_heads=self.H)
        self.layer_norm1 = nn.LayerNorm(self.D)
        self.layer_norm2 = nn.LayerNorm(self.D)
        
        self.mlp = nn.Sequential(nn.Linear(self.D, self.neurons * self.D),
                                nn.GELU(),
                                nn.Linear(self.neurons * self.D, self.D))
    
    def forward(self, x, causal=True):
        # Multi-Head Self-Attention
        x_attn = self.msha(x, causal)
        # LayerNorm
        x = self.layer_norm1(x_attn + x)
        # MLP
        x_mlp = self.mlp(x)
        # LayerNorm
        x = self.layer_norm2(x_mlp + x)
        
        return x

# %% [markdown]
# ### Architecture Note: Layer Normalization
# Deep Transformers are notoriously difficult to train due to vanishing/exploding gradients. To stabilize training, this architecture employs **Layer Normalization** (`nn.LayerNorm`) within each `TransformerBlock`.
#
# By normalizing the inputs across the feature dimension before passing them to the Attention and MLP layers (or after, depending on specific Pre/Post-LN configuration), we ensure consistent mean and variance, allowing for deeper networks (10 blocks in this configuration) and higher learning rates (`1e-3`).

# %%
class LossFun(nn.Module):
    def __init__(self,):
        super().__init__()
        
        self.loss = nn.NLLLoss(reduction='none')
    
    def forward(self, y_model, y_true, reduction='sum'):
        # y_model: B(atch) x T(okens) x V(alues)
        # y_true: B x T      
        B, T, V = y_model.size()
        
        y_model = y_model.view(B * T, V)
        y_true = y_true.view(B * T,)
        
        loss_matrix = self.loss(y_model, y_true) # B*T
        
        if reduction == 'sum':
            return torch.sum(loss_matrix)
        elif reduction == 'mean':
            loss_matrix = loss_matrix.view(B, T)
            return torch.mean(torch.sum(loss_matrix, 1))
        else:
            raise ValueError('Reduction could be either `sum` or `mean`.')

# %%
class Transformer(nn.Module):
    def __init__(self, num_tokens, num_token_vals, num_emb, num_neurons, num_heads=2, dropout_prob=0.1, num_blocks=10, device='cpu'):
        super().__init__()
        
        # hyperparams
        self.device = device
        self.num_tokens = num_tokens
        self.num_token_vals = num_token_vals
        self.num_emb = num_emb
        self.num_blocks = num_blocks
        
        # embedding layer
        self.embedding = torch.nn.Embedding(num_token_vals, num_emb)
        
        # positional embedding
        self.positional_embedding = nn.Embedding(num_tokens, num_emb)
        
        # transformer blocks
        self.transformer_blocks = nn.ModuleList()
        for _ in range(num_blocks):
            self.transformer_blocks.append(TransformerBlock(num_emb=num_emb, num_neurons=num_neurons, num_heads=num_heads))
        
        # output layer (logits + softmax), Q:WHY Logit?
        self.logits = nn.Sequential(nn.Linear(num_emb, num_token_vals))
        
        # dropout layer
        self.dropout = nn.Dropout(dropout_prob)
        
        # loss function
        self.loss_fun = LossFun()
        
    def transformer_forward(self, x, causal=True, temperature=1.0):
        # x: B(atch) x T(okens)
        # embedding of tokens
        device='cpu'
        x = self.embedding(x) # B x T x D
        # embedding of positions
        pos = torch.arange(0, x.shape[1], dtype=torch.long).unsqueeze(0).to(self.device)
        pos_emb = self.positional_embedding(pos)
        # dropout of embedding of inputs
        x = self.dropout(x + pos_emb)
        
        # transformer blocks
        for i in range(self.num_blocks):
            x = self.transformer_blocks[i](x)
        
        # output logits
        out = self.logits(x)
        
        return F.log_softmax(out/temperature, 2)
    
    @torch.no_grad()
    def sample(self, batch_size=4, temperature=1.0):
        x_seq = np.asarray([[self.num_token_vals - 1] for i in range(batch_size)])

        # sample next tokens
        for i in range(self.num_tokens-1):
            xx = torch.tensor(x_seq, dtype=torch.long, device=self.device)
            # process x and calculate log_softmax
            x_log_probs = self.transformer_forward(xx, temperature=temperature)
            # sample i-th tokens
            x_i_sample = torch.multinomial(torch.exp(x_log_probs[:,i]), 1).to(self.device)
            # update the batch with new samples
            x_seq = np.concatenate((x_seq, x_i_sample.to('cpu').detach().numpy()), 1)
        
        return x_seq
    
    @torch.no_grad()
    def top1_rec(self, x, causal=True):
        x_prob = torch.exp(self.transformer_forward(x, causal=True))[:,:-1,:].contiguous()
        _, x_rec_max = torch.max(x_prob, dim=2)
        return torch.sum(torch.mean((x_rec_max.float() == x[:,1:].float().to(device)).float(), 1).float())
    
    def forward(self, x, causal=True, temperature=1.0, reduction='mean'):
        # get log-probabilities
        log_prob = self.transformer_forward(x, causal=causal, temperature=temperature)
        
        return self.loss_fun(log_prob[:,:-1].contiguous(), x[:,1:].contiguous(), reduction=reduction)

# %% [markdown]
# ### Auxiliary functions: training, evaluation, plotting

# %%
def evaluation(test_loader, name=None, model_best=None, epoch=None, device='cpu'):
    # EVALUATION
    if model_best is None:
        # load best performing model
        model_best = torch.load(name + '.model', weights_only=False).to(device)

    model_best.eval()
    loss = 0.
    rec = 1.
    N = 0.
    for indx_batch, test_batch in enumerate(test_loader):
        loss_t = model_best.forward(test_batch.to(device), reduction='sum')
        loss = loss + loss_t.item()
        
        rec_t = model_best.top1_rec(test_batch.to(device))
        rec = rec + rec_t.item()
        
        N = N + test_batch.shape[0]
    loss = loss / N
    rec = rec / N

    if epoch is None:
        print(f'FINAL LOSS: nll={loss}, rec={rec}')
    else:
        print(f'Epoch: {epoch}, val nll={loss}, val rec={rec}')

    return loss, rec

def plot_curve(name, nll_val, ylabel='nll'):
    plt.plot(np.arange(len(nll_val)), nll_val, linewidth='3')
    plt.xlabel('epochs')
    plt.ylabel(ylabel)
    plt.savefig(name + '_' + ylabel + '_val_curve.pdf', bbox_inches='tight')
    plt.close()

# %%
def training(name, max_patience, num_epochs, model, optimizer, training_loader, val_loader, device='cpu'):
    nll_val = []
    rec_val = []
    best_nll = 1000.
    patience = 0
    device='cpu'
    # Main loop
    for e in range(num_epochs):
        # TRAINING
        model.train()
        for indx_batch, batch in enumerate(training_loader):
            loss = model.forward(batch.to(device))

            optimizer.zero_grad()
            loss.backward(retain_graph=True)
            optimizer.step()

        # Validation
        loss_val, r_val = evaluation(val_loader, model_best=model, epoch=e)
        nll_val.append(loss_val)  # save for plotting
        rec_val.append(r_val)

        if e == 0:
            print('saved!')
            torch.save(model, name + '.model')
            best_nll = loss_val
        else:
            if loss_val < best_nll:
                print('saved!')
                torch.save(model, name + '.model')
                best_nll = loss_val
                patience = 0
            else:
                patience = patience + 1

        if patience > max_patience:
            break

    nll_val = np.asarray(nll_val)
    rec_val = np.asarray(rec_val)

    return nll_val, rec_val

# %% [markdown]
# ### Initialize dataloaders

# %%
train_data = Tox21(mode='train')
val_data = Tox21(mode='val')
test_data = Tox21(mode='test')

training_loader = DataLoader(train_data, batch_size=64, shuffle=True)
val_loader = DataLoader(val_data, batch_size=64, shuffle=False)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)

result_dir = 'results/'
if not(os.path.exists(result_dir)):
    os.mkdir(result_dir)
name = 'transformer_gen'

# %% [markdown]
# ### Hyperparams

# %% [markdown]
# ### Model Configuration & Hyperparameters
# The model is configured to balance computational efficiency with expressivity for the Tox21 SMILES vocabulary:
#
# * **Attention Heads (H=8):** Multiple heads allow the model to attend to different chemical properties simultaneously (e.g., one head might focus on ring closure, another on valency).
# * **Embedding Dimension (D=64):** A compact representation sufficient for the limited vocabulary size of SMILES tokens (112 unique values).
# * **Depth (10 Blocks):** Deep enough to capture long-range dependencies in molecular structures, such as opening and closing rings over long distances.

# %%
num_tokens = 101
num_token_vals = 112
num_emb = 64
num_neurons=4
num_heads=8
num_blocks=10
causal=True

lr = 1e-3 # learning rate
num_epochs = 200 # max. number of epochs
max_patience = 10 # an early stopping is used, if training doesn't improve for longer than 20 epochs, it is stopped

if torch.cuda.is_available():
    device = 'cuda'
else:
    device = 'cpu'

# %%
evaluation
# Out:
# <function __main__.evaluation(test_loader, name=None, model_best=None, epoch=None, device='cpu')>

# %% [markdown]
# ### Initialize Transformer

# %%
model = Transformer(num_tokens=num_tokens, num_token_vals=num_token_vals, num_emb=num_emb, num_neurons=num_neurons, num_heads=num_heads, num_blocks=num_blocks, device=device)
model = model.to(device)
# Print the summary (like in Keras)
print(summary(model, torch.zeros(1, num_tokens, dtype=torch.long).to(device), show_input=False, show_hierarchical=False))
# Out:
# Transformer by JT.
# ---------------------------------------------------------------------------
#           Layer (type)        Output Shape         Param #     Tr. Param #
# ===========================================================================
#            Embedding-1        [1, 101, 64]           7,168           7,168
#            Embedding-2        [1, 101, 64]           6,464           6,464
#              Dropout-3        [1, 101, 64]               0               0
#     TransformerBlock-4        [1, 101, 64]         166,016         166,016
#     TransformerBlock-5        [1, 101, 64]         166,016         166,016
#     TransformerBlock-6        [1, 101, 64]         166,016         166,016
#     TransformerBlock-7        [1, 101, 64]         166,016         166,016
#     TransformerBlock-8        [1, 101, 64]         166,016         166,016
#     TransformerBlock-9        [1, 101, 64]         166,016         166,016
#    TransformerBlock-10        [1, 101, 64]         166,016         166,016
#    TransformerBlock-11        [1, 101, 64]         166,016         166,016
#    TransformerBlock-12        [1, 101, 64]         166,016         166,016
#    TransformerBlock-13        [1, 101, 64]         166,016         166,016
#              Linear-14       [1, 101, 112]           7,280           7,280
#             LossFun-15                  []               0               0
# ===========================================================================
# Total params: 1,681,072
# Trainable params: 1,681,072
# Non-trainable params: 0
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Let's play! Training

# %%
# OPTIMIZER
optimizer = torch.optim.Adamax([p for p in model.parameters() if p.requires_grad == True], lr=lr)

# %%
device
# Out:
# 'cpu'

# %%
# Training procedure
nll_val, rec_val = training(name=result_dir + name, max_patience=max_patience, num_epochs=num_epochs, model=model, optimizer=optimizer,
                           training_loader=training_loader, val_loader=val_loader)
# Out:
# Epoch: 0, val nll=64.78763397216797, val rec=0.8337499952316284
# saved!
# Epoch: 1, val nll=54.70233673095703, val rec=0.8494749975204468
# saved!
# Epoch: 2, val nll=49.981326751708984, val rec=0.8577000093460083
# saved!
# Epoch: 3, val nll=46.763358459472656, val rec=0.8637500119209289
# saved!
# Epoch: 4, val nll=43.999794006347656, val rec=0.8710500073432922
# saved!
# Epoch: 5, val nll=42.2609147644043, val rec=0.8751499915122986
# saved!
# Epoch: 6, val nll=40.41671371459961, val rec=0.8784500002861023
# saved!
# Epoch: 7, val nll=38.67744140625, val rec=0.8843000221252442
# saved!
# Epoch: 8, val nll=37.314358978271486, val rec=0.8871249961853027
# saved!
# Epoch: 9, val nll=36.00353210449219, val rec=0.891000018119812
# saved!
# Epoch: 10, val nll=35.24253753662109, val rec=0.8931249928474426
# saved!
# Epoch: 11, val nll=34.636759185791014, val rec=0.8946250009536744
# saved!
# Epoch: 12, val nll=33.7612956237793, val rec=0.8974750208854675
# saved!
# Epoch: 13, val nll=33.42655288696289, val rec=0.896150016784668
# saved!
# Epoch: 14, val nll=31.719208068847657, val rec=0.9032250070571899
# saved!
# Epoch: 15, val nll=31.538875579833984, val rec=0.9021749901771545
# saved!
# Epoch: 16, val nll=31.135436401367187, val rec=0.903349986076355
# saved!
# Epoch: 17, val nll=30.375762329101562, val rec=0.9071250176429748
# saved!
# Epoch: 18, val nll=30.536268463134764, val rec=0.9061750078201294
# Epoch: 19, val nll=29.624066314697266, val rec=0.907299988269806
# saved!
# Epoch: 20, val nll=29.437589797973633, val rec=0.9089750194549561
# saved!
# Epoch: 21, val nll=28.640594787597657, val rec=0.9117750072479248
# saved!
# Epoch: 22, val nll=28.286980514526366, val rec=0.9121499681472778
# saved!
# Epoch: 23, val nll=28.3411572265625, val rec=0.911875
# Epoch: 24, val nll=28.178621292114258, val rec=0.912875018119812
# saved!
# Epoch: 25, val nll=27.778633499145506, val rec=0.9138750076293946
# saved!
# Epoch: 26, val nll=27.814232330322266, val rec=0.9136250019073486
# Epoch: 27, val nll=27.67405990600586, val rec=0.9141500282287598
# saved!
# Epoch: 28, val nll=27.251765899658203, val rec=0.9143999910354614
# saved!
# Epoch: 29, val nll=27.32708023071289, val rec=0.915150032043457
# Epoch: 30, val nll=27.371617050170897, val rec=0.9149249982833862
# Epoch: 31, val nll=26.97275604248047, val rec=0.9161750054359437
# saved!
# Epoch: 32, val nll=26.84409225463867, val rec=0.9169500303268433
# saved!
# Epoch: 33, val nll=26.787518081665038, val rec=0.9172500276565552
# saved!
# Epoch: 34, val nll=26.596804580688477, val rec=0.9180499887466431
# saved!
# Epoch: 35, val nll=26.173484802246094, val rec=0.9213250231742859
# saved!
# Epoch: 36, val nll=26.57867401123047, val rec=0.9184250164031983
# Epoch: 37, val nll=26.35125846862793, val rec=0.9202250146865845
# Epoch: 38, val nll=26.58791030883789, val rec=0.9177000093460083
# Epoch: 39, val nll=26.286464004516603, val rec=0.9197250366210937
# Epoch: 40, val nll=25.98688674926758, val rec=0.9206999945640564
# saved!
# Epoch: 41, val nll=26.354479751586915, val rec=0.9206500291824341
# Epoch: 42, val nll=26.106004486083986, val rec=0.9207250213623047
# Epoch: 43, val nll=26.18784812927246, val rec=0.9207999968528747
# Epoch: 44, val nll=26.13599739074707, val rec=0.9220750093460083
# Epoch: 45, val nll=26.05227592468262, val rec=0.9214750242233276
# Epoch: 46, val nll=26.646983489990234, val rec=0.9196250104904174
# Epoch: 47, val nll=26.00738182067871, val rec=0.9230250048637391
# Epoch: 48, val nll=26.13750717163086, val rec=0.9225000071525574
# Epoch: 49, val nll=26.353769454956055, val rec=0.9219750118255615
# Epoch: 50, val nll=26.94641548156738, val rec=0.9207499980926513
# Epoch: 51, val nll=28.075098876953124, val rec=0.9190500259399415

# %%
test_loss, test_rec = evaluation(name=result_dir + name, test_loader=test_loader)

with open(result_dir + name + '_test_loss.txt', "w") as f:
    f.write('Test NLL: ' + str(test_loss)+'\n'+'Test REC: ' + str(test_rec))
    f.close()

plot_curve(result_dir + name, nll_val, ylabel='nll')
plot_curve(result_dir + name, rec_val, ylabel='rec')
# Out:
# FINAL LOSS: nll=27.498341779011053, rec=0.9166341455971322

# %%
##for H=4
#FINAL LOSS: nll=27.146774961890245, rec=0.9189268251744712
##for H=1
#FINAL LOSS: nll=27.463991341939785, rec=0.9144146430783155
##for H=8
#FINAL LOSS: nll=27.498341779011053, rec=0.9166341455971322

# %% [markdown]
# ### Data visualization

# %% [markdown]
# #### Auxiliary functions

# %%
def is_valid_smiles(smiles):
    """ Using RDKit to calculate whether molecule is syntactically and semantically valid.
    """
    if smiles == "":
        return False
    try:
        return Chem.MolFromSmiles(smiles, sanitize=True) is not None
    except:
        return False

# %%
def plot_smiles(smiles, nrows, ncols, path=None):

    if len(smiles) < nrows * ncols:
        raise AssertionError("Provide more examples")

    fig, axes = plt.subplots(nrows, ncols)
    plt.subplots_adjust(wspace=0., hspace=0.)
    idx = 0
    for row in [idx for idx in range(nrows)]:
        for column in [idx for idx in range(ncols)]:
            ax = axes[row, column]
            # ax.set_title(f"Image ({row}, {column})")
            ax.axis('off')
            ax.imshow(Draw.MolToImage(Chem.MolFromSmiles(smiles[idx])))
            idx += 1
    if path:
        plt.savefig(path, dpi=300, bbox_inches='tight')
        plt.tight_layout()
    else:
        plt.show()

# %% [markdown]
# #### Sample new data

# %%
# Sample molecules
model_best = torch.load(result_dir + name + '.model', weights_only=False)
model_best = model_best.eval()

# %%
num_samples = 1028
x_sample = model_best.sample(batch_size=num_samples)

# %%
alphabet_dict_reverse = np.load(os.path.join('molecules', 'alphabet_dict_reverse.npy'), allow_pickle=True).item()

# %%
smiles = []
for n in range(x_sample.shape[0]):
    s = ''
    for i in range(1, x_sample.shape[1]):
        c = alphabet_dict_reverse[x_sample[n, i]]
        if c == 'unk':
            break
        else:
            s = s + c
    if is_valid_smiles(s):
        smiles.append(s)

# %%
smiles
# Out:
# ['O=C(O)C(Cl)Cl',
#  'Cc1ncc(NCCO)nc1',
#  'COc1ccc(C(=O)CC=C(Cl)Cl)cc1',
#  'O=[PH](O)c1nc(Cl)cnc1Cl',
#  'COC(=O)c1ccc(OC(C)=O)cc1',
#  'N=C(N)NC(=S)NCCCSC',
#  'C=CCCCCCCCCCO',
#  'NCCCNC(=O)SC(=O)O',
#  'CC(O)[C@H]1[C@@H](O)C[C@H](O)[C@H](O)C1',
#  'CCOC(=O)C(c1ccccc1)C1=NCNCN1',
#  'COc1nc(CN)cc(-c2cccc(S(N)(=O)=O)c2)c1N',
#  'CC(C)CC(=O)N(c1ccc(F)c(Cl)c1)C(=O)OCCCl',
#  'CO/N=C(\\CC#N)NOC(=O)C',
#  'CCCCCC[N+](C)(C)CCCC',
#  'CCCCN1C(=O)C(c2ccccc2)CC1',
#  'CC(C)Cc1ccc(C(=O)O)cc1',
#  'CN(C)CCN=Cc1c[nH]c2ccccc12',
#  'CC(CCO)(C)OC(C)COCOc1ccccc1',
#  'CCOP(=O)(OCC)CCSP(=O)(OCC)OC',
#  'CC(C)(c1c(O)cc(O)cc1)c1ccc(Cl)cc1',
#  'CCCCCCCCCOCO',
#  'Nc1ccc(CO)cc1',
#  'CCC(CCCO)OCCOc1ccccc1',
#  'O=C(C/C=C/c1ccc(O)cc1)/C=C1C/CCCCCC(=O)OCC1',
#  'O=C1NC(=O)c2cnncc21',
#  'CCCCn1c(N)nc(-c2ccccc2)n1',
#  'Nc1cccc2c(S(=O)(=O)O)cccc12',
#  'CC(=O)[O-].[Mo]',
#  'COCCCCCCCN(C)C(=O)N(CCCC)C(=O)OCCCCc1ccc(Cl)cc1OC',
#  'O=C(O)CCN1CCCCCC1',
#  'BrC(Br)C(Br)Br',
#  'C=COC1CC(C)OC1',
#  'O=C([O-])CCCOCC(=O)c1ccccc1',
#  'CC(C)N1C(=O)[C@H](N[C@H]2C(=O)O)[C@@H](O)[C@H]2NC1',
#  'CC(C)OC(=O)C(Cl)=C(Cl)Cl',
#  'OCc1ccc(F)cc1',
#  'NC(=O)CC(Cl)Cl',
#  'COC(=O)c1ccc(Cl)cc1Cl',
#  'COc1ccc(S(=O)=O)cc1',
#  'O=S(=O)([O-])OS(=O)(Cl)Cl',
#  'CCn1nc(S)c2nc(N)c(N)nc21',
#  'CCCCCCCCCCCCCOS(=O)(=O)[O-]',
#  'O=[N+]([O-])[O-].[Na+]',
#  'COC(=O)c1ccccc1',
#  'O=C1COCc2ccccc21',
#  'C[C@H]1Nc2ccccc2C1',
#  'CC(C(C)C1OC(=O)/C=C/C1=C(O)/C=C/C1=C(\\Cl)C1=C(\\C)C(C)C(C)C(C)(C)C)C(O)C(C)C(C)C',
#  'CCCOC(C)OC(=O)CCl',
#  'O=c1[nH]c2ccccc2c(O)n1',
#  'CC(C)COC(=O)NCCN(CC)c1ccc([N+](=O)[O-])cc1',
#  'CCCCCCCCCCOC(=O)N(C)C(=O)OCC(C)CC',
#  'FC(F)(F)c1ccc(I)c(Cl)c1',
#  'CN1CCCCC1CN=O',
#  'COC(=O)CCCC(=O)O',
#  'NC1CNCc2ccccc21',
#  'COC(=O)c1ccc([N+](=O)[O-])cc1',
#  'O=C(O)CCc1cccc(O)c1',
#  'C=CC1CC=CC(O)CCCCC1',
#  'OCCCNc1ccc(Br)cc1',
#  'C(C)/C(=N)C(=O)OC(C)C',
#  'CC(C)(O)OC(=O)COc1ccccc1',
#  'CC1(C)N=C(N)NC(=O)NNC1=O',
#  'CCOC(=O)COCC#N',
#  'CC(CN(C)C(=O)N[C@@H]1Cc2ccccc2Sc2ccccc21)C(=O)[C@@H](O)Cc1ccccc1',
#  'CC(=O)OC/C=C(/C)OC(C)C',
#  'CC(C)COC(=O)c1ccccc1N',
#  'CO/N=C(\\COC(N)=O)c1ccccc1C(=O)O',
#  'CCCCCC[N+](C)CC(=O)O',
#  'O=Cc1ccc(Cl)c(Cl)c1',
#  'O=C(CCc1ccc(O)cc1)c1cccc(C(=O)O)c1',
#  'CCCCOC(CC)OCC(C)OC(=O)C1CCN(Cc2ccccc2)c2ccc([N+](=O)[O-])cc21',
#  'NC(=O)N[C@@H](NC(=O)CC(=O)O)C(=O)NP(=O)(O)O',
#  'CN(C)CC1=CC(O)C=C1',
#  'O=C(O)c1cc(Cl)c(Cl)c(Cl)c1',
#  'S=[N+]([O-])O',
#  'O=C(Nc1ccccc1)OCCc1ccccc1Br',
#  'CO[Si](C)(OCC)OC',
#  'COc1cc2[nH]c(N)nc(=O)c2[nH]1',
#  'CC(C)CCc1ccccc1N',
#  'CC(C)OP(=O)(OC(CC)OC(C)C)OC(C)C',
#  'CC/C=C(\\C)COc1ccc(O)cc1',
#  'O=C(OCc1ccccc1)c1ccccc1',
#  'O=[N+]([O-])c1ccc([N+](=O)[O-])cc1',
#  'CN(C)c1ccc(N=Nc2ccc(Cl)cc2)cc1',
#  'CC(C)OS(=O)(=O)O',
#  'COP(=O)(OC)OC(Cl)Cl',
#  'OCCc1ccccc1',
#  'CCCCc1cc(OC)c(O)cc1C',
#  'CCN(CCCCO)C(=O)c1ccc(O)cc1',
#  'CC(C)OP(=O)(Oc1ccccc1)N1CC(C)CCC1',
#  'NC(=O)c1ccccc1',
#  'Cc1ccc(-c2ccc(N)cc2)cc1',
#  'CCCCCCCCCCOC(=O)C(C)CCCCC',
#  'CCCCCCCCCCS(=O)N(C)C',
#  'CCCCCCCCCCCCCCCCC(=O)O',
#  'COC(=O)CSSSCC(=O)OC',
#  'O=C(CCCCCCC1CCCC1)N1CC(=O)NCC1=O',
#  'CC(C)CCCCCCC(=O)OCC(C)C',
#  'COC(=O)Nc1nc(N)c(Cl)c(Cl)c1',
#  'CC(=O)c1ccc(/C(=N)NC(=O)Nc2ccc([Si](=O)[O-])cc2)cc1',
#  'O=[N+]([O-])c1cccc(Cl)c1',
#  'C/N=C(/C=C1C(C)SCC1)N1CCCCC(C)S(C)C1',
#  'CC(C)C(=O)O',
#  'CC(=O)O[C@]1(O)CCC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4(C)[C@H]3C[C@@]21C',
#  'CCC(CN)(CC(C)O)C(C)NC(=O)c1ccccc1',
#  'Cc1ccc(Cc2ccccc2)cc1',
#  'CCCCN(CCCC)CC(C)c1ccc(CC(C)C)cc1',
#  'CCCCCCCCCCOC(C)C(=O)O',
#  'ON1CN(c2ccc(Cl)cc2)CCCC1',
#  'O=C(O)C1CCC(CO)C1',
#  'CCCC[n+]1ccc[n+](C)c1',
#  'CO[Si](OC)(OC)OC',
#  'N#CC1(C=NCC2CCCC2)CCCCN1C=O',
#  'C/CN=C(/C(=O)O)N=Cc1ccccc1',
#  'O=C(O)Cc1ccc(CO)cc1',
#  'COc1ccc2c(c1)O[C@@H]1CC[C@@]2(COC(NC(C)O[C@@](C)(O)C)O[C@H]3)[C@H](O)[C@H](CO)[C@H]31',
#  'OCc1cccc2ccccc12',
#  'CCCOc1ccc(OCC(O)=O)cc1',
#  'O=C1CCCCCCCCCCCNCC(=O)N1NCOCCO',
#  'C=CCOC(=O)CCCCCC(C)Cc1ccccc1',
#  'Nc1ccc([N+](=O)[O-])c(C(F)F)c1',
#  'O=C1c2cccc([N+](=O)[O-])c2C(=O)N1CCO',
#  'CCCCCCCCCCCCCCCC(=O)O',
#  'CCOC(=O)c1ccc(OCC(O)CNCCN(C)C)cc1',
#  'CN1C(=O)C(c2ccccc2)S(=O)(=O)c2ccccc21',
#  'C=C(C)C(=O)OCCCOC(C)(C)C',
#  'CCN1C(=O)N=C(c2cccs2)c2occc2C1=O',
#  'C[C@@H](C)C[C@@H]1CC[C@H](O)C(=O)O1',
#  'CC(C)N=Nc1ccc([N+](=O)[O-])cc1',
#  'OOCCC(c1ccccc1)c1ccccc1',
#  'BrC(Br)=C(Br)Br',
#  'O=C(O)CCOCCCl',
#  'O=C(O)Cc1ccc([N+](=O)[O-])cc1',
#  'COC(=O)CCC(=O)OC',
#  'Cc1ccc2sc3ccccc3c2c1O',
#  'CC(C(=O)[O-])c1ccc([N+](=O)[O-])cc1',
#  'O=S(=O)([O-])C=[N+]1/COC1',
#  'CC(O)c1ccc(O)cc1',
#  'NC(C(=O)O)c1ccncc1',
#  'O=[N+]([O-])c1ccc([O-])c(Br)c1',
#  'CCCCOCCOC1CO1',
#  'C=C(C)[C@H]1CC[C@@H](O)[C@@H](O)[C@H]1N',
#  'O=C(c1ccccc1)Cc1ccccc1',
#  'CCC(C)(C)OC(=O)CC(=O)O',
#  'CCN1CCCC1CNC(=O)c1cc(Cl)ccc1OC',
#  'CN1[C@H]2CC[C@@H]1[C@H](OC(O)C(O)c1ccccc1)C2',
#  'CO/N=C(/C(=O)[O-])C(=O)O[Ba+2]Cl',
#  'CCN(CC)C(=O)N/C(C)=C(S)N(C)C(=O)OC',
#  'CCCCCCCCCCCCOP(=O)(O)O',
#  'NCCC(=O)O',
#  'NC(=O)N=O',
#  'CC(C)(CC(=O)O)C(=O)O',
#  'CCCCCCOC(=O)CCC(CC)C',
#  'CC(C)C(=O)OC(C)(C)C',
#  'OCCNCCCCN1CCNCC1',
#  'CC(C)CCCCCCOC(=O)CC(C)C',
#  'O=C([O-])CS',
#  'O=C(O)COc1cc(CO)ccc1O',
#  'CCCCCCCCCNS(=O)(=O)O',
#  'O=C(O)CN1CCOC1',
#  'Nc1ccc(NS(=O)c2ccccc2)cn1',
#  'CN1CCOC(c2ccc(F)cc2)c2ccccc21',
#  'Oc1ccc(O)cc1',
#  'O=C(NO)c1ccccc1',
#  'C=C1C(=O)O[C@H](CO)[K+]C/C=C/C/C=C(/C)C1C',
#  'CN(C)C(=S)N(C)S(=O)(=O)[O-]',
#  'C/C(=C\\c1ccccc1)Nc1ccccc1',
#  'O=C([O-])c1cc(Cl)ccc1Cl',
#  'CN1CCN(C(c2ccccc2)c2ccccc2)CC1[Sn]',
#  'ClSC(=O)N=NCC1CCCCCC1',
#  'O=[N+]([O-])c1ccccc1C1CNCNCC1',
#  'Nc1ccc([N+](=O)[O-])cc1[N+](=O)[O-]',
#  'N=C(N)C(=O)OCCCSCCCCCCC[P+]',
#  'Oc1ccc(Oc2ccccc2)cc1',
#  'CC(CSC[N+](C)C)CSC(=O)O',
#  'CC(C)(C)Nc1ccc(O)cc1',
#  'O=C1c2ccccc2C(=O)C1c1cccc2cc(O)ccc12',
#  'O=C(CCO)CNCCO',
#  'CC(C)N(C(C)C)C1CCC(C)C(C)C1',
#  'CCCC(N)C(=O)OCC(O)CO',
#  'CC(C)([N+](=O)[O-])C(=O)N(c1ccc(Cl)cc1)c1ccccc1',
#  'CCCC[P+](Cl)(CCC)CCl',
#  'CCCCc1nc(N)nc(/C=C/C(CCCCCC)CC)n1',
#  'CCN(CC)C(O)c1ccccc1',
#  'OCC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO',
#  'Clc1ccc(C(c2ccccc2)C2CCCCN2)cc1',
#  'CCCCCC(C)S(=O)(=O)[O-]',
#  'CC(C)(c1ccccc1)C(Cl)(Cl)Cl',
#  'CCCNP(Oc1ccccc1)OCC',
#  'CCOP(=S)(OCC)OC(C)C',
#  'O=C/C=C/C=C/c1ccccc1',
#  'CN(C)c1cc(N2CCCC2)c2sccc2c1',
#  'N#CCCC1CC(c2ccc(Cl)cc2)CCC1',
#  'Oc1cccc2[nH]cnc12',
#  'CCCCCCCCCCCCCC[Hg]',
#  'C=CC(=O)OCC',
#  'O=C(O)c1ccc(C(=O)O)cc1',
#  'CS(=O)(=O)c1cc(C)nc(C)n1',
#  'O=S(=O)(c1ccc(Cl)cc1)c1ccc(Cl)cc1',
#  'CCCCCCOCCOCCOCCOCCOCCOC[C@@H](C)CCC',
#  'CCCCCCCCCCCC[N+](C)(C)COC(=O)c1ccccc1',
#  'CC1=NC(NC[C@H]2CC(=O)OC2)C(=O)N1',
#  'N#CCP(O)(CBr)C[O-]',
#  'OC[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)CO',
#  'CC(C)(C)C(=O)C(O)C(=O)O',
#  'CN1C(N(CO)C(N)CNC(N)(C)C)CC1',
#  'N/C=C/c1ccc2ncccc2c1',
#  'O=C(C(=O)Nc1ccccc1)Sc1cccnc1',
#  'COc1ccc(C(C)=O)c(C)c1',
#  'C=CC(=O)OCCOC(=O)[C@@H]1O[C@H]([C@H](CO)CO[C@@H]2[C@H](C)[C@H](O)[C@@H]2O)[C@H](O)CO1',
#  'NC(=O)N=O',
#  'O=C(O)C(O)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F',
#  'CC(C)C(C)OC(C(C)(C)C)CNC(C)C(C)Cl',
#  'Oc1cccc2ccncc12',
#  'C=CC(C)CCCCCC(C)C',
#  'CCN(CCOc1ccc(Cl)cc1)C1CN(CC(O)Cc2ccc(F)cc2)CC1',
#  'CC(C)Oc1ccc(Cl)cc1',
#  'CS(=O)(=O)C(N)=O',
#  'CCCP(CC)(OP(N)=O)C',
#  'C#CN1CCN(CN(C)CCN(c2ccccc2)c2ccoc2)CC1',
#  'CC(C)(C)C(=O)OCC/C=C1/C2=C(C)CCC[C@H]3[C@@H](CC(=O)CC[C@H]3[C@@H]2CC)[C@@H](O)[C@H]1c1ccccc1',
#  'CNC(=O)c1ccc(C)cc1',
#  'NS(=O)(=O)c1cc(NC(=O)O)ccc1',
#  'CC(c1ccc(F)cc1)[C@@H](C)NC[C@H]1CN2CCS[C@H]12',
#  'O=C(O)[C@H](O)C(=O)O',
#  'O=S(=O)(c1ccccc1)c1ccc(O)cc1',
#  'CO[Si](C)(C)COC',
#  'CCOP(=S)(OC)SCSC',
#  'C=CC(C)(Cl)C(Cl)Cl',
#  'COC(=O)C1=C(C(=O)O)C(C)(C)NC(C)C1c1cnc(C)n1C',
#  'O=C(Nc1ccccc1)c1ccccc1',
#  'CC[P+](CC)(CCCN)CC(=O)Nc1cccc(C)c1',
#  'NCCCNCCN',
#  'CC(C)OC(O)C(=O)O',
#  'Cc1cc(C(C)C)cc(C)c1C(C)(C)C',
#  'C[Sn](Cl)(Cl)Cl',
#  'COC(C)(C)OC',
#  'CC(C)CCOc1ccccc1O',
#  'O=[N+]([O-])c1ccc2oc(=O)[nH]c2c1',
#  'CC(C)/C(C)=C/C(O)C(C)=C(\\C)CC(C)C',
#  'O=C(Cl)c1ccccc1[N+](=O)[O-]',
#  'O=C(O)COCCO',
#  'CC(C)(O)CCCC(=O)O',
#  'O=[N+](c1ccco1)Sc1ccccc1',
#  'CCOS(CO)(=O)OC/OC(C)=O',
#  'CCCCCCC(C)/C=C\\C(=O)OCCCCCC',
#  'O=[N+]([O-])[O-]',
#  'CCCCCCCCCCn1cc[n+](C)c1',
#  'O=[N+]([O-])c1ccccc1CO',
#  'Nc1ccccc1C(=O)O',
#  'C[C@H](COc1ccccc1)c1ccccn1',
#  'C1CN(CCNC2CCCC2)CCC1',
#  'CCNS(=O)(=O)c1ccc(C(=O)O)cc1',
#  'O=[N+]([O-])c1ccc(-c2ccc(O)cc2)cc1',
#  'CN(C)c1ccc(CC(=O)O)cc1',
#  'CCN(CC)CCOC(=O)C1(c2ccccc2)CCCC1',
#  'CCCCOC(=O)C(C)=O',
#  'CC1(C)O[C@@H](C)[C@H](N)CO[C@H]1O',
#  'CCCCOP(=O)(OCCCC)OCCC',
#  'CCN(CC)CCOC(=O)COc1cc(C)ccc1C',
#  'O=C1CCCCCCC1',
#  'O=C(O)c1c(Cl)cccc1Cl',
#  'O=C(O)c1ccc(O)cc1',
#  'C[N+](C)(C)COC(=O)Cc1cc(Cl)ccc1Cl',
#  'O=C(O)CCC(=O)O',
#  'O=C(O)CCCCCCBr',
#  'N#CNC(c1ccccc1)C(F)(F)F',
#  'CCC[Si](NCC)(OC)OC',
#  'CCCCN1C[C@@H](O)[C@H](O)[C@H](O)[C@H]1C',
#  'CCOCCOCCOCCOCC',
#  'C=CCCCCCCCCCCCC',
#  'CC(C)(C)CC1CC=C(C)CC1',
#  'O=C1c2ccccc2C(=O)C1c1cccc2ccccnn12',
#  'CCCCCCCCCCCCCC(=O)OC(=O)CS(=O)(=O)CC(C)O',
#  'CCN(CCO)C(=O)c1ccc(C(=O)O)cc1',
#  'COc1ccc(CCCCCN2CCC[C@@H](O)CC2)c(OC)c1',
#  'CC(C)C(O)c1ccccc1',
#  'COc1cccc(CN(C)CCC(O)COc2ccccc2)c1OC',
#  'C#C[C@]1(O)CC[C@H]2[C@@H]3CCCC4=CCC(=O)CC[C@]4(C)[C@@H]3CC[C@@]21C',
#  'CCCCC(CC)COC(C)=O',
#  'NC1CCNc2ccc(N)c(N)s2C1',
#  'CCCCn1cc[n+](C)c1C',
#  'COS(=O)(=O)[O-].[C@H]1CCOSS(=O)(=O)O[C@@H]1OCOC(c1ccccc1)=SC',
#  'CN(C)CCn1cnc2ccccc21',
#  'CCCCOC(=O)CC(=O)OCC(C)C',
#  'N=C(N)N=C(N)N',
#  'CCCCOC(=O)COCC(C)=O',
#  'CC(C)(C)[C@H](N)C(=O)OC(C#N)=O',
#  'N#Cc1c(Br)cc(O)c(OCC(F)(F)F)c1Br',
#  'C[C@H]Oc1ccc(S(=O)(=O)NC(=O)NC(=O)O)cc1',
#  'CCCCCCCCCCCCBr',
#  'CCOP(CCCCl)OP(=O)(OCC)OCC',
#  'CC(C)OC(=O)[C@@H](O)[C@H]1O[C@H]([C@@H](O)CCl)[C@@H](O)[C@@H](O)[C@H](O)[C@H]1O',
#  'CCN1C(=O)c2nc3c(cccc3)C(=O)N2C1',
#  'CCCCCC(=O)OCC(C)C',
#  'CCOc1cc(C(=O)c2cccs2)cc(O)c1',
#  'Nc1ccsc1',
#  'CC(C)(C)N(CC(=N[C@H](CC)N)C(=N)/C(C)C#N)NC(=O)NO',
#  'O=C(O)Cc1ccccc1',
#  'C[N+]1(C)[C@H]2CC[C@@H]1C[C@@H](OC(=O)C(CO)c1cnc[nH]1)C2',
#  'CCOC(=O)c1cccnc1',
#  'O=C(O)CNc1nncnc1Cc1ccccc1',
#  'CO/N=C(\\C(=O)O)C(=O)OC',
#  'CCC(C#N)C(=O)Nc1cncnc1C(=O)O',
#  'CC[C@H](N)C(=O)O',
#  'O=C(Cc1ccccc1)Oc1ccccc1',
#  'CCCCOC(CO)OC(C)C',
#  'O=S(O)Cn1cc(Cl)cc1Cl',
#  'COP(=S)(OC)Oc1ccccc1',
#  'O=[N+]([O-])c1ccc(C(F)(F)F)cc1',
#  'O=C(c1ccccc1CCc1cnccc1)c1ccccc1',
#  'Cc1nc(C(=O)NNc2cnc(NC(=O)NC(=O)Nc3ccoc3)cc2)ccn1',
#  'CCOC(=O)COc1ccccc1',
#  'CCCCCCCCCCCCCCc1ccccc1',
#  'C=CCCCCCCCOC(C)=O',
#  'NC(CO)(CO)CO',
#  'CCN(CC)C(=O)OCC(O)COc1ccc(OC)nc1',
#  'O=S(=O)(O)CO',
#  'CCCCCCCCCCCCCCSC[P+](C)(C)C',
#  'CCCCCCCCCCCC(=O)OCC',
#  'CN(C)C(=O)Nc1cc(Oc2ccccc2)cc(C(=O)O)c1',
#  'Fc1ccc(Br)cc1',
#  'CNC(=O)Oc1ccccc1C(=O)c1ccccc1',
#  'COc1ccc(N)cc1',
#  'Cc1ccc(CCO)c(C(O)CCl)c1',
#  'O=c1cc[nH]c2ccccc12',
#  'Oc1ccc(Nc2ccccc2)cc1',
#  'CC(C)CCCCCO',
#  'O=C(Nc1ccc([N+](=O)[O-])cc1)Nc1ccccc1',
#  'O=C(Cl)CN1CCC2C(=CCCCC2)CCC1',
#  'C=CCC(=O)OCCCOC(C)=O',
#  'CC(C)(C)C(=O)OCCc1ccccc1',
#  'C=CCNC(=N)N1NCC(C)NCCCS1',
#  'CN(C)CCCN1c2sccs2Cc2ccc(N)cc21',
#  'C=CC(=O)CCCCC',
#  'CCCCN(CCCCO)c1c(Cl)cc(Cl)nc1N',
#  'CCN(CC)c1ccccc1',
#  'CC(C)(C)c1ccccc1',
#  'O=C(O)c1ccc([C@@H](C(=O)O)N[C@@H]2CCC2)cc1',
#  'CC(C)(c1ccc(O)cc1)c1ccccc1',
#  'CC(C)N(C)C',
#  'Cc1nc(=O)[nH]cn1',
#  'NC(=O)NC(=O)O',
#  'COP(=S)(OC)SCS',
#  'CCOC(=S)SSs1(SOC(=O)CCOC2)c(-c3cccs3)c(c3ccncc23)c(OC)c1',
#  'C=C(C)C(=O)OCCCCCCNCCCOC(C)C(=O)OCC(=O)CO',
#  'CCCCCCC[C@H](CC)C(=O)O[C@H]1C[C@@H](CC(=O)O)[C@H](O)C[C@@H](O)[C@H]1O',
#  'O=C(O)C(Cl)Cl',
#  'CCN(CC)N1CCCCN(C(c2ccccc2)c2ccc(F)cc2)CC1',
#  'C=CC(C)(CCC=O)CCC(C)C',
#  'CC(C)(O)C(=O)Nc1ccccc1C(=O)c1ccccc1',
#  'CCCCCCCCCCOC(=O)N(C)CC(=O)[O-]',
#  'O=[N+]([O-])c1ccccc1[N+](=O)[O-]',
#  'CC/C=C\\CCOC(=O)CC(C)C',
#  'CCCCC[P+](CCC)CCCCCCC',
#  'CC(C)(O)C(=O)c1ccccc1',
#  'O=S(=O)(O)c1ccccc1',
#  'COc1ncnc(S(=O)(=O)OCC)n1',
#  'O=C(O)c1ccc2nc[nH]c2c1',
#  'O=[N+]([O-])OCCCO[N+](=O)[O-]',
#  'c1ccc2c3nnc(NS(N)(=O)=O)[nH]c3cccc2c1',
#  'CN(C)C(=S)SC(=S)N(C)C',
#  'O=C(c1ccc(O)c(O)c1)c1ccc(Cl)c(Cl)c1',
#  'O=C([O-])CCO',
#  'CCN(CC)c1nc(N)c(N/C=C/N\\c2ccc(N)cc2)cc1',
#  'CC1CN(c2ccc(Cl)c(Cl)c2)CC1',
#  'CCOP(=S)(OC)OCCn1nc2ccccc2c1',
#  'CC1CCC(O)C[C@@H]1NCCCCl',
#  'NC(C(=O)c1ccc(Cl)cc1)NSc1ccco1',
#  'Nc1cccc(S(=O)(=O)O)c1',
#  'CC=CCC(=O)OCC=Cc1ccccc1',
#  'Cc1ccc(N)cc1',
#  'CN(C)CCN1c2ccccc2Cc2cccc(Cl)c21',
#  'CN1CCSC(Oc2cccs2)C1',
#  'CC(C)OC(=O)c1ccc(Cl)cc1Cl',
#  'O=C(C(CCl)Cl)Nc1cc(Cl)ccc1',
#  'C[C@@H](OCO)[C@H]1O[C@H]([C@@H](O)[C@@H](O)[C@H](O)[C@H](O)CO)[C@H](O)[C@H]1O',
#  'C=C1CC[C@H](C)C/C1',
#  'O=S(=O)([O-])c1ccccc1S(=O)(=O)c1ccccc1',
#  'CCCCC[N+](C)CCCCCC',
#  'CCCOC(=O)c1cc(OC(C)OC=O)c(OC(C)CC)cc1O',
#  'O=C(O)c1ccccc1-c1ccccc1',
#  'CCN(CC)NC(=O)[C@H]1C(=O)N2C(=O)[C@@H](O)[C@@H](O)C[C@H]2O1',
#  'CCC(C)(C)OC(C)=O',
#  'O=C1[C@H](O)[C@@H](NCc2cccs2)[C@H](NO)[C@@H]1O',
#  'O=C(O)CNCCCO',
#  'CCOP(=O)(OCC)Oc1ccccc1',
#  'O=C([O-])C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)F',
#  'C=C(C)C(=O)OCCCCCCOCC(C)=C',
#  'C[n+]1ccnc([NH+])s1Cc1cc(O)ccc1',
#  'CCCCCCCCCCCCCCCS(=O)=C/C=N/C(C)Nc1ccnc(NC)n1',
#  'CCCCC(O)C1CCC(C)SC1',
#  'CC(C)(C)c1ccc(N=C(O)CCCCN(CCC=O)N2CCCCC2)cc1',
#  'COc1ccc(Cc2ccc(C(C)C)cc2)cc1',
#  'O=C(NCc1ccccn1)c1ccc([N+](=O)[O-])cc1',
#  'O=C([O-])c1ccc(O)cc1',
#  'CC(C)NCC(N)=O',
#  'CCCCCOC(=O)CCCCCCCC',
#  'Oc1cc(Cl)cc(Cl)c1',
#  'CCC[N+]1(C)CCCC1',
#  'Nc1nc2cncn2n1CO',
#  'CCCCC[Sn](Cl)(Cl)[C@](C)(=O)Cl',
#  'CCOP(=O)(SC[N+](C)CC)OCC',
#  'C=CCCCCCCC(C)CC',
#  'CCN1CCN(c2cc(N)c(N)cc2)OC1',
#  'CCO[Si](CCCSSSSCCCC)OCC',
#  'O=[N+]([O-])c1ccc([N+](=O)[O-])cc1',
#  'CCCOC(=O)CCCC',
#  'CCC(C)(O)Cc1ccc(CNCCN(C)CC)cc1',
#  'CCOP(=O)(SCC)SCCS',
#  'CC(C)NC(=O)c1cccc(CN(C)C)c1',
#  '[Cr].[Fe+3].F.[Na+]',
#  'ClCCOCCn1cncn1',
#  'CC(C)NCc1ncnc2ncnn12',
#  'C=C(C)C(=O)OCC(C)C',
#  'CC(C)(C)/C=C1/C(=C(\\c2cccs2)c2ccccc2)N(C)C1=O',
#  'CCSC(C)(Cl)C(Cl)(Cl)Cl',
#  'O=C(O)c1cc(-c2ccccc2)co1',
#  'CCCCC1CC(=O)S(=O)(O)C1',
#  'NC(=O)N[C@@H](CS)C(=O)OCC(=O)O',
#  'CCCCOC(=O)CCCCl',
#  'COC(=O)C=C(c1ccccc1)c1ccccn1',
#  'NC(=O)N/[C@H](N)N=C/c1cc(Cl)ccc1N',
#  'CCCCOC(=O)c1cccc(NC(=O)OCCCC)n1',
#  'N=C=NCCCCSCCCCCSCCCl',
#  'Nc1ncnc2c1ncn2[C@@H]1O[C@H](O)[C@@H](O)[C@@H]1O',
#  'OC(Br)Br',
#  'CCCc1cc(O)c(O)cc1',
#  'CCCc1cc(C(C)C)ccc1',
#  'CCC(C(N)COC(=O)NCC(c1cccs1)[C@@H]1O[C@H](CO)CO2)ccc2c(C(C)CCC2)NCN1CCCCCC2',
#  'C#CC[N+]1(O)CC[C@@H]2[C@H]3CCC4=CCC(=O)CC[C@@]43C[C@@]21C',
#  'C=CCCCCCCCCCCCCC(=O)OCCCN(C)CC',
#  'Cc1ccc2c(c1)C(=O)OC2',
#  'O=S(=O)([O-])CCN1CCNCSS1',
#  'BrC1CC(O)CC(Br)C(Br)C1',
#  'CCCC/C=C/C=CO',
#  'COC(C)C(C)OCCN',
#  'CN1CCN(c2ccccc2)C(C)SC1',
#  'O=C([O-])CCc1ccccc1C(=O)Nc1ccccc1',
#  'CCCCCCCCCCCCCC(C)O',
#  'COC(=O)C(Cc1ccccc1)c1ccccc1',
#  'CC(=O)C=Cc1ccc(C)cc1',
#  'CN(C)CCCC(O)COc1ccc(C(C)(C)C)cc1',
#  'CCOC(=O)OC/C=C/c1ccc2c(n[nH]c2C)nc(Nc2ccccc2)c1',
#  'CC(C)COCn1cccnc1=O',
#  'OCCN1CCCN(CCO)CC1',
#  'O=C(Cl)CCCl',
#  'CCCCCCCCC1CO1',
#  'ClCCOCC(c1ccccc1)c1ccccc1',
#  'CCOC(=O)c1cc(C(=O)CN2CCN(Cc3ccccc3)C2)cc(C)n1',
#  'OC(F)(F)C(F)(F)C(F)(F)C(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F',
#  'OC[C@H]1O[C@](O)(CO)[C@H](O)[C@@H](O)[C@@H]1O',
#  'COc1cc(C)cc2c(O)cccc12',
#  'Cc1ccccc1S(=O)(=O)[O-]',
#  'NC(=O)Nc1ccccc1',
#  'O=Nc1ccc(Cl)cc1',
#  'O=C([O-])CC(Br)Br',
#  'O[C@]1(I)CCCO1',
#  'CCCCCCCCCOC(=O)COc1sc(C)cc1',
#  'CCCCCCCCCC(C)/C=C\\CCCCCCCCC(C)\\C=C\\C=C\\C-C=C(C)\\CC(=O)OCC(C)(C)C',
#  'COc1ccccc1N',
#  'Cc1ccc([N+](=O)[O-])cc1',
#  'CN(C)c1ccc(O)c(C(C)C)c1',
#  'O=C(CCCBr)NC(=O)CNCn1cncn1',
#  'Cc1cc(Cl)c(SO)cc1',
#  'O=C(/C=C/c1cc[nH]c1)-c1ccc(Cl)cc1',
#  'N#CC1CC1CC=O',
#  'CC(C)CC(C)O',
#  'CC(C)(C)NC(=O)c1ccc(O)cc1',
#  'CN(C)[C@@H]1[C@@H](O)Cc2nnc3ccc(N)ccc3c2c1',
#  'C=C1CC[C@H](CCC(O)CO)S1',
#  'CC(C)CCCCCCCCOC(C)=O',
#  'O=[N+]([O-])c1ccc(Br)cc1',
#  'O=C1OC(=O)[C@@]2(O)C[C@H]3[C@@H](CC=C[C@]3(C)[C@@]21CC2)[C@@]2(Cl)N(C(=O)Cl)O',
#  'NC(=O)N[C@@H](O)[C@H]1O[C@H](Cl)[C@@H](O)[C@@H](O)[C@H](O)[C@H](O)[C@@H](S[C@H]1O)CO',
#  'CCCN(CCC)C(=O)c1ccccc1S(=O)(=O)NC(=O)N1CCCCC1',
#  'COc1ccccc1N1CCCN(CCN(CC(=O)N[C@@H]2CCCCCCC2)c2ccccc2)CCCC1',
#  'CCC(C)CC(C)C.Oc1ccc(CO)c(O)n1',
#  'COc1ccc(NC=Nc2ccccc2C(=O)c2ccccc2)cc1',
#  'CCOC(=O)c1ccc(N)cc1',
#  'S=CSc1ccc(CCN(C)CC=Cc2ccc(S(=O)NC=Nc3ccccc3)cc2)c(N)c1',
#  'CN(C)C1=N/c2ncc(N)nc2Cc2ccccc21',
#  'CCCCCCOCCOC(C)=O',
#  'OC[C@H]1O[C@H](O[C@H]2OP(O[N+](C#N)=O)O[C@H](CO)[C@@H]2O)[C@@H](O)[C@H](O)[C@H](O)[C@@H](O)[C@H]1O',
#  'CCCCCCCCSCCCC',
#  'CC(C)OC(=O)c1ccccc1',
#  'O=P(O)(O)OCC[Ca+2]',
#  'CNC(=O)NC(N)C',
#  'NC(CSOC(=O)C(F)(F)F)Nc1ccccc1',
#  'CCCCCCCCCCCCCCCCC(=O)OCC(CO)C(=O)OCC(C)C',
#  'O=C(O)c1c(I)cc(O)c(I)c1',
#  'COc1cc(C)c2ncc3cccc3c(OC)c(N)cc2c1',
#  'O=C(O)CC(=O)O',
#  'BrCC(F)(Cl)Cl',
#  'CN(C)CCOc1ccccc1',
#  'CCC(C)OC(O)COC(C)C',
#  'CC1CCC(N)CCN1CCCCc1ccccc1',
#  'Cc1cc(O)c(N)cc1C',
#  'CCCOCCOCCO',
#  'O=C(O)C(O)C(=O)O',
#  'c1cnc2c(c1)ccc1cccnc12',
#  'OC[C@@H](O)[C@H](O)[C@H](O)[C@H](O)CO',
#  'CC1(CCOC(=O)O)CCCCCCCC1',
#  'CC(C)(O)Cc1cccnc1',
#  'O=C(O)CCc1ccc(Cl)cc1',
#  'CCCOC(=O)c1ccccc1',
#  'CCC(CO)(CO)COC(CO)=O',
#  'CC1(N=O)C(C)OC(=O)[C@@H]1N=c1scc([N+](=O)[O-])cc1',
#  'C=C(C)Cc1ccccc1C',
#  'CC(N)[C@@H](O)C(=O)O',
#  'CCOC(C)OCC(c1ccccc1)[C@@H](C)C(=O)N1CN[C@H](C(=O)O)Cc2cnccc21',
#  'CCN(CC)CCOC(C)N',
#  'CCCCCCCCCC[Si](CC)OC1CN(c2ccc(Cl)cc2)CC1',
#  'CCCCCCCCCCCC1(CO)CC(C(=O)OC1)C(=O)O',
#  'C[N+](C)(C)C',
#  'O=C(O)CCCCCCCCN(C)',
#  'O=C(CO)Cc1cccc(Cl)c1',
#  'O=S(=O)(O)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F',
#  'CCCCCCCCCCN(CCC)C1CCC(O)C(C(C(N)=O)=CC1)NC(=O)[O-]',
#  'Nc1cc(S(=O)(=O)O)ccc1C(=O)O',
#  'C=C(C)C1CCC=C[C@H]1',
#  'CC(=O)NC(=O)O',
#  'CCCC[N+]1(C)CCCC1.O=S(=O)([N-]S(=O)(=O)C(F)(F)F)NC(F)(F)C(F)(F)C(F)(F)C(F)(F)F',
#  'Nc1ccc(-c2ccccc2)cc1',
#  'O=C(O)CCN1C=CCN1',
#  'CC(=O)N=O',
#  'O=C(C=Cc1ccc[nH]1)Nc1ccc(O)cc1',
#  'O=[N+]([O-])c1ccc([N+](=O)[O-])cc1',
#  'NC(Cc1ccccc1)CCc1ccccc1',
#  'OC1[C@H](O)CCCC1',
#  'CC1(C)[Bi](O)O[C@H](CN(CC#N)c2ccccc2)C1(C)c1ccccc1',
#  'O=S(=O)([O-])c1ccccc1',
#  'CN(C)CCCN1c2ccccc2CCc2ccccc21',
#  'C[C@H](CN1CCN(CCc2ccccc2)c2ccncc21)C',
#  'CCCCCCCC1CC(=O)O1',
#  'Cc1c(CC(=O)[O-])c([N+](=O)[O-])n(C)n1',
#  'CCOP(=O)(OCC)OCC',
#  'CCCCCCCCCO',
#  'CN(C)Cc1ncccn1',
#  'O=S(=O)(O)CCl',
#  'O=C(NCc1cccnc1)c1ccccc1',
#  'CCCCCC/C=C/C=C/C=C/CC(=O)OC',
#  'O=C(Cl)CCl',
#  'CC(C)[S+]c1ccc(O)cc1',
#  'CSc1c2ncc(N(C)C)c(S(O)(C)=O)sc2c(N)s1',
#  'CC(C)(C(=O)O)c1ccc(O)cc1',
#  'C=Cc1ccc(C2CCC2(CCO)Cc2cccs2)cc1',
#  'N=C(N)Nc1ccc(Cl)cc1',
#  'O=S(=O)(O)c1ccccc1S(=O)(=O)c1ccc(O)cc1',
#  'CC(C)Oc1ccccc1',
#  'O=c1cc([C@H](CCO)c2ccccc2)oc2cc(O)ccc12',
#  'CC(C)(C)C(=O)O',
#  'COCCOc1ccc(Br)cc1S(=O)N(C)C(=O)Oc1ccc(Cl)c(Cl)c1',
#  'CCCCCCC[n+]1ccc(C)cc1',
#  'COC(=O)[C@H](c1ccccc1)C(=O)O[C@H](C)C/C=C/C[N+](C)C=C(C)C',
#  'CCCCN1C[C@H](S)Cc2ccc(N3CCCN3)cc21',
#  'CCCCCCC(C)OC(=O)Nc1ccc(O)c(O)c1',
#  'CCCCCCS[N+](C)(C)Cc1ccc(OC)nc1',
#  'Cc1nc(=O)oc2cccnc12',
#  'O=[N+]([O-])c1c(F)cccc1F',
#  'O=S(=O)([O-])[Fe+3][Si]([O-])(Br)O.I',
#  'CC[N+](C)(C)C',
#  'c1ccc(CNCc2ccccc2)cc1',
#  'CC(=O)OC/C=C(\\C)CCCCCCCC',
#  'CC(C)COc1ccccc1O',
#  'CC(C)Nc1ccccc1OC(=O)Nc1ccccc1C(F)(F)F',
#  'CCCCCCCCCCCC(=O)OCC[C@H]1CN(C)CC1',
#  'OC(O)c1ccccc1O',
#  'CN1CCC[C@@H](Cc2c[nH]c3cc[nH]c23)CCCC1',
#  'CC(=O)Oc1cc[nH]c1',
#  'CC(C)c1ccccc1N(C)C',
#  'CC(CC(C)NC(=O)[N+](O)[O-])Cc1ncsc1',
#  'O=NN(c1ccccc1)c1ccccn1',
#  'CC1(C)C(=O)C(O)OC1',
#  'C=C(C)C(=O)OCCc1cc(-c2csc(N3CCCCO3)c2)ccc1',
#  'O=C1C(CO)CCC(=O)N1CCO',
#  'CCCC(C)c1ccc(O)c(O)c1',
#  'O=C(O)CNC(=O)c1c(I)c(CC(=O)O)ccc1I',
#  'CCCCCC(C)COc1ccccc1',
#  'CCCOc1ccc(N)nc1',
#  'Oc1ccc(Cl)cc1Cl',
#  'CCCCCCCCCCCCCCC',
#  'CCCCCCCCCCCCCCCCCCCCC(=O)OCC',
#  'O=C(O)c1ccc2ncccc2c1',
#  'O=C(Cl)c1ccccc1Cl',
#  'CS(C)(C)NC/C=C/c1cccc(Cl)c1',
#  'CCN(CC)C(=O)CC(Cl)(Cl)Cl',
#  'CCn1cc[n+](C)c1C.O=S(=O)([N-]S(=O)(=O)C(F)(F)F)C(F)(F)F',
#  'CC(C)(C)CC(CP(C)(O)CO)Cc1ccccc1',
#  'CC1(C)CC(=O)C(Br)=C1Br',
#  'CCOP(=O)(OCC)Oc1ccc([N+](=O)[O-])o1',
#  'O=C(CCl)CCCl',
#  'CCCCOc1nc(NS(=O)(=O)CCN(CC)CCCC)cnc1N',
#  'CC(C)C(C)CC(C)NOCC#N',
#  'CN1C(=O)c2ccccc2C1=O',
#  'O=C([O-])C1CCCCC1',
#  'NNc1cccc(Cl)c1',
#  'N#CC(=O)N1CCCCCC1',
#  'CCC(C)OC(=O)OC(C)OC(=O)OCO',
#  'CC(C)(C)COC(=O)c1ccc(Cl)cc1',
#  'COC(=O)c1ncc([N+](=O)[O-])nc1',
#  'OCc1ccc(-c2ccc(CC(F)(F)F)cc2)cc1',
#  'CC(C)N(CC)NC(=O)CCO',
#  'CN(C)CCCCN1c2ccccc2Cc2ccc(Cl)cc21',
#  'NC(Cc1ccc(F)cc1)C(=O)O',
#  'CCN(CC)CCO',
#  'Cc1ccc(C)cc1C.F',
#  'CN(C)C(=O)CC(O)(c1ccccc1)c1ccccc1',
#  'Nc1nc2cc(N)cc(O)c2[nH]1',
#  'CC(C)(C)C(=O)c1ccc(C(=O)OC#N)cc1',
#  'CC(C)[C@@H](O)C(=O)O',
#  'Cl[Se](Cl)Cl',
#  'COc1cc(Cl)c(NCCN(C)OC)cc1OC',
#  'CC(c1ccc(O)cc1)c1ccc(S(=O)(=O)O)cc1',
#  'c1ncc2c(c1)sc1ncncc12',
#  'O=C(O)c1ccc(C(C)O)cc1',
#  'CCN(CC)C(=S)[S-]',
#  'C#C[C@]1(O)CC[C@H]2[C@@H]3C[C@H](OC)C4=CC(=O)CC[C@]4(C)[C@@]3CC[C@@]21C',
#  'CCCCCCCC[N+](CCCCCC)(O)CCOP(=O)(OCC[N+](C)CC)OCCCCC',
#  'O=Cc1ccccc1F',
#  'C(=C/c1ccccc1)\\c1ccccn1',
#  'CC1CCC(O)CC1C',
#  'CCC(CO)(COCOC(=O)c1ccccc1)c1ccccc1',
#  'CC/C=C\\CCOC(=O)CCCCCCCC(=O)OC(C)CC',
#  'CS(=O)(=O)O',
#  'COCCCOc1ccccc1CCCC(=O)OCC',
#  'NS(=O)(c1ccccc1)c1ccccc1O',
#  'CCCCCCS/C=C\\C=C/C=C/C=C\\CCCCCCCC(=O)O',
#  'COc1ccc(NCCCc2c[nH]c3ccccc23)c(OOC)c1OC',
#  'C=CC(=O)OCCOCC(=O)C1=CCCC1C(C)CC',
#  'COCCN(C)C',
#  'Nc1cnc(CO)c(O)c1',
#  'CNCC(O)COc1ccc(C(C)(F)F)cc1',
#  'O=[N+]([O-])c1ccc(C=Cc2ncnc3ccc(Cl)cc23)cc1',
#  'COc1ccc(OC)cc1',
#  'N=COc1ccccc1',
#  'CCOc1ccc(OCC)cc1',
#  'O=[N+]([O-])c1cc(Oc2ccccc2)ccc1O',
#  'C=C1CC[C@H](O)C[C@@H]1F',
#  'Cc1cc(C)cc(C(=O)[O-])c1',
#  'CC[N+]1(C)CCCC(OC(=O)C(O)(c2ccccc2)c2ccccc2)C1',
#  'COCC(C)(C)O',
#  'COC(C)(C)OC',
#  'CCOC(=O)SSSC(C)COC',
#  'CN(C)CCCN1c2ccccc2Sc2ccc(Cl)cc21',
#  'COP(=S)(O)Oc1ccccc1',
#  'CC(C)OP(=O)(O[N+](C)(C)C)OC(=O)N1CCCCC1',
#  'C=COCC(C)C',
#  'COC(CNC(C)=O)c1ccccc1[O-]',
#  'NNC(=O)c1ccc(C=C2CCCN(CNCCCN(c3cc(Cl)ccc3)C2ccc(Cl)(F)cc2)CCC2)cc1',
#  'CCC(C)N1CN(c2cc(O)c(I)c(N)c2)C1=O',
#  'CC(Cc1ccc(O)cc1)C(=O)N1CCN(c2ccccc2)c(S(=O)(=O)[O-])c1',
#  'COc1ccc([N+](=O)[O-])c(C(=O)OCCCN(C)C)c1',
#  'OCCc1ccccn1',
#  'CC(C)N1C(=O)OCO1',
#  'CCCCCCCCCCCCOC(=O)CO',
#  'CCCCC/C=C\\C=O',
#  'CCCCCCOC(=O)C(=O)O',
#  'CCOC(=O)CC(Cl)C(=O)Cl',
#  'CCCCCCCC[Si](OC)(O)OCC',
#  'OC[C@H](O)[C@@H](O)[C@H](O)CO',
#  'CCC(=O)N1CC(=O)C[C@H](C)N1',
#  'CC(C)CCCN(CCC)CCCOC(=O)CC(C)C',
#  'CCCCCCCCCCCCCCCCCCCBr.OCCCO',
#  'O=C1c2ccccc2C(=O)C=C1c1ccc(O)cc1',
#  'C=CCN1CC[C@H](/C=C\\Cc2scc[n+]2C)CN1',
#  'CC(C)=CCCC(=O)O',
#  'O=C(O)C1CCC(=C(c2ccccc2)OC1)C(Cl)Cl']

# %%
print(f'The percentage of valid molecules: {len(smiles)/num_samples}')
with open(result_dir + name + '_validity.txt', "w") as f:
    f.write(f'The percentage of valid molecules: {len(smiles)/num_samples}')
    f.close()
# Out:
# The percentage of valid molecules: 0.6498054474708171

# %%
plot_smiles(smiles, 6, 6, path=result_dir + 'transformer_generated_molecules.png')
